# %%
# !pip install cx_Oracle
# Out:
# ...
#      |████████████████████████████████| 852 kB 13.6 MB/s
# ...

# %%
import cx_Oracle
import os

LOCATION = r"C:\app\user\product\21c\dbhomeXE"
os.environ["PATH"] = LOCATION + ";" + os.environ["PATH"] #환경변수 등록

connect = cx_Oracle.connect("yiji", "1234", "localhost:1521/xe")
cursor = connect.cursor()

cursor.execute("select in_no from KYO_IN where rownum < 20")

for i in cursor : print(i)
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-3-35f7ad378b1e> in <module>()
#       5 os.environ["PATH"] = LOCATION + ";" + os.environ["PATH"] #환경변수 등록
#       6
# ----> 7 connect = cx_Oracle.connect("yiji", "1234", "localhost:1521/xe")
#       8 cursor = connect.cursor()
#       9
#
# DatabaseError: DPI-1047: Cannot locate a 64-bit Oracle Client library: "libclntsh.so: cannot open shared object file: No such file or directory". See https://cx-oracle.readthedocs.io/en/latest/user_guide/installation.html for help
